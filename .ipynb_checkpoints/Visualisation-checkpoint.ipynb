# %% [markdown]
# # Visualisation

# %% [markdown]
# Sur cette section, nous allons effectuer différentes opérations de visualisation sur notre jeu de données initialement récolté et nettoyé.

# %%
# Module pandas pour manipuler le dataframe ensuite constitué :
import pandas as pd

# Module numpy pour manipuler essentiellement des arrays :
import numpy as np

# Modules pour la visualisation :
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# On importe la base de données nettoyée :

# %%
df = pd.read_csv("data/data_cleaned.csv", sep = "\t")

# %%
df.head(10)
# Out:
#        tconst                             title  year  runtime  \
# 0  tt13143964       Borat: Subsequent Moviefilm  2020       95
# 1   tt1070874               Les Sept de Chicago  2020      129
# 2   tt2235695                           Rebecca  2020      121
# 3  tt10682266                   Hubie Halloween  2020      102
# 4   tt2222042                 Love and Monsters  2020      109
# 5   tt0805647                 Sacrées sorcières  2020      106
# 6   tt0107120  Hocus Pocus: Les trois sorcières  1993       96
# 7  tt10362466                 After: Chapitre 2  2020      105
# 8   tt7846844                      Enola Holmes  2020      123
# 9   tt6723592                             Tenet  2020      150
#
#                                   genres  rate   votes           director  \
# 0                     Comedy               7.0   50191      Jason Woliner
# 1   Drama, History, Thriller               7.9   37295       Aaron Sorkin
# 2    Drama, Mystery, Romance               6.0   11829       Ben Wheatley
# 3   Comedy, Fantasy, Mystery               5.2   27526       Steven Brill
# 4  Action, Adventure, Comedy               7.1   10780   Michael Matthews
# 5  Adventure, Comedy, Family               5.4    5605    Robert Zemeckis
# 6    Comedy, Family, Fantasy               6.9   97876       Kenny Ortega
# 7             Drama, Romance               5.2    7501       Roger Kumble
# 8    Adventure, Crime, Drama               6.6   91329     Harry Bradbeer
# 9             Action, Sci-Fi               7.8  138378  Christopher Nolan
#
#                                              casting
# 0  ['Sacha Baron Cohen', 'Maria Bakalova', 'Tom H...
# 1  ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...
# 2  ['Lily James', 'Armie Hammer', 'Kristin Scott ...
# 3  ['Adam Sandler', 'Kevin James', 'Julie Bowen',...
# 4  ["Dylan O'Brien", 'Jessica Henwick', 'Michael ...
# 5  ['Anne Hathaway', 'Octavia Spencer', 'Stanley ...
# 6  ['Bette Midler', 'Sarah Jessica Parker', 'Kath...
# 7  ['Josephine Langford', 'Hero Fiennes Tiffin', ...
# 8  ['Millie Bobby Brown', 'Henry Cavill', 'Sam Cl...
# 9  ['John David Washington', 'Robert Pattinson', ...

# %% [markdown]
# ## Visualisation henri

# %% [markdown]
# Il serait pertinent d'étudier les tendances de préférences pour les films selon leur genres principaux.

# %% [markdown]
# Pour ce faire, comme de nombreux films possèdent plusieurs genres, on va devoir split la base de données :

# %%
df_test = df.head(10) # Test sur 10 films

# %%
s = df_test["genres"].str.split(',').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'genres'
del df_test['genres']
df_genres = df_test.join(s)

# %%
s
# Out:
# 0       Comedy
# 1                    Drama
# 1                  History
# 1     Thriller
# 2                    Drama
# 2                  Mystery
# 2      Romance
# 3                   Comedy
# 3                  Fantasy
# 3      Mystery
# 4                   Action
# 4                Adventure
# 4       Comedy
# 5                Adventure
# 5                   Comedy
# 5       Family
# 6                   Comedy
# 6                   Family
# 6      Fantasy
# 7                    Drama
# 7      Romance
# 8                Adventure
# 8                    Crime
# 8        Drama
# 9                   Action
# 9       Sci-Fi
# Name: genres, dtype: object

# %%
df_genres
# Out:
#        tconst                             title  year  runtime  rate   votes  \
# 0  tt13143964       Borat: Subsequent Moviefilm  2020       95   7.0   50191
# 1   tt1070874               Les Sept de Chicago  2020      129   7.9   37295
# 1   tt1070874               Les Sept de Chicago  2020      129   7.9   37295
# 1   tt1070874               Les Sept de Chicago  2020      129   7.9   37295
# 2   tt2235695                           Rebecca  2020      121   6.0   11829
# 2   tt2235695                           Rebecca  2020      121   6.0   11829
# 2   tt2235695                           Rebecca  2020      121   6.0   11829
# 3  tt10682266                   Hubie Halloween  2020      102   5.2   27526
# 3  tt10682266                   Hubie Halloween  2020      102   5.2   27526
# 3  tt10682266                   Hubie Halloween  2020      102   5.2   27526
# 4   tt2222042                 Love and Monsters  2020      109   7.1   10780
# 4   tt2222042                 Love and Monsters  2020      109   7.1   10780
# 4   tt2222042                 Love and Monsters  2020      109   7.1   10780
# 5   tt0805647                 Sacrées sorcières  2020      106   5.4    5605
# 5   tt0805647                 Sacrées sorcières  2020      106   5.4    5605
# 5   tt0805647                 Sacrées sorcières  2020      106   5.4    5605
# 6   tt0107120  Hocus Pocus: Les trois sorcières  1993       96   6.9   97876
# 6   tt0107120  Hocus Pocus: Les trois sorcières  1993       96   6.9   97876
# 6   tt0107120  Hocus Pocus: Les trois sorcières  1993       96   6.9   97876
# 7  tt10362466                 After: Chapitre 2  2020      105   5.2    7501
# 7  tt10362466                 After: Chapitre 2  2020      105   5.2    7501
# 8   tt7846844                      Enola Holmes  2020      123   6.6   91329
# 8   tt7846844                      Enola Holmes  2020      123   6.6   91329
# 8   tt7846844                      Enola Holmes  2020      123   6.6   91329
# 9   tt6723592                             Tenet  2020      150   7.8  138378
# 9   tt6723592                             Tenet  2020      150   7.8  138378
#
#             director                                            casting  \
# 0      Jason Woliner  ['Sacha Baron Cohen', 'Maria Bakalova', 'Tom H...
# 1       Aaron Sorkin  ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...
# 1       Aaron Sorkin  ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...
# 1       Aaron Sorkin  ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...
# 2       Ben Wheatley  ['Lily James', 'Armie Hammer', 'Kristin Scott ...
# 2       Ben Wheatley  ['Lily James', 'Armie Hammer', 'Kristin Scott ...
# 2       Ben Wheatley  ['Lily James', 'Armie Hammer', 'Kristin Scott ...
# 3       Steven Brill  ['Adam Sandler', 'Kevin James', 'Julie Bowen',...
# 3       Steven Brill  ['Adam Sandler', 'Kevin James', 'Julie Bowen',...
# 3       Steven Brill  ['Adam Sandler', 'Kevin James', 'Julie Bowen',...
# 4   Michael Matthews  ["Dylan O'Brien", 'Jessica Henwick', 'Michael ...
# 4   Michael Matthews  ["Dylan O'Brien", 'Jessica Henwick', 'Michael ...
# 4   Michael Matthews  ["Dylan O'Brien", 'Jessica Henwick', 'Michael ...
# 5    Robert Zemeckis  ['Anne Hathaway', 'Octavia Spencer', 'Stanley ...
# 5    Robert Zemeckis  ['Anne Hathaway', 'Octavia Spencer', 'Stanley ...
# 5    Robert Zemeckis  ['Anne Hathaway', 'Octavia Spencer', 'Stanley ...
# 6       Kenny Ortega  ['Bette Midler', 'Sarah Jessica Parker', 'Kath...
# 6       Kenny Ortega  ['Bette Midler', 'Sarah Jessica Parker', 'Kath...
# 6       Kenny Ortega  ['Bette Midler', 'Sarah Jessica Parker', 'Kath...
# 7       Roger Kumble  ['Josephine Langford', 'Hero Fiennes Tiffin', ...
# 7       Roger Kumble  ['Josephine Langford', 'Hero Fiennes Tiffin', ...
# 8     Harry Bradbeer  ['Millie Bobby Brown', 'Henry Cavill', 'Sam Cl...
# 8     Harry Bradbeer  ['Millie Bobby Brown', 'Henry Cavill', 'Sam Cl...
# 8     Harry Bradbeer  ['Millie Bobby Brown', 'Henry Cavill', 'Sam Cl...
# 9  Christopher Nolan  ['John David Washington', 'Robert Pattinson', ...
# 9  Christopher Nolan  ['John David Washington', 'Robert Pattinson', ...
#
#                   genres
# 0     Comedy
# 1                  Drama
# 1                History
# 1   Thriller
# 2                  Drama
# 2                Mystery
# 2    Romance
# 3                 Comedy
# 3                Fantasy
# 3    Mystery
# 4                 Action
# 4              Adventure
# 4     Comedy
# 5              Adventure
# 5                 Comedy
# 5     Family
# 6                 Comedy
# 6                 Family
# 6    Fantasy
# 7                  Drama
# 7    Romance
# 8              Adventure
# 8                  Crime
# 8      Drama
# 9                 Action
# 9     Sci-Fi

# %% [markdown]
# L'opération devient beaucoup plus longue pour tous les films de la base. Afin de s'épargner de ce temps d'attente, nous avons effectué l'opération uniquement une fois puis save la base désirée pour tous les films sous le nom de *data_genres_split.csv* sur le GitHub dans le dossier **data**. Nous l'utiliserons ainsi pour faire les analyses désirées concernant les genres

# %% [markdown]
# On charge ainsi la base *data_genres_split* :

# %%
df_genres_split = pd.read_csv("data/data_genres_split.csv", sep = "\t")

# %% [markdown]
# La base est bien chargée :

# %%
df_genres_split
# Out:
#          index      tconst                        title  year  runtime  rate  \
# 0            0  tt13143964  Borat: Subsequent Moviefilm  2020       95   7.0
# 1            1   tt1070874          Les Sept de Chicago  2020      129   7.9
# 2            1   tt1070874          Les Sept de Chicago  2020      129   7.9
# 3            1   tt1070874          Les Sept de Chicago  2020      129   7.9
# 4            2   tt2235695                      Rebecca  2020      121   6.0
# ...        ...         ...                          ...   ...      ...   ...
# 343714  188252   tt0182675               Adsiz cengaver  1970       83   5.5
# 343715  188252   tt0182675               Adsiz cengaver  1970       83   5.5
# 343716  188253   tt2794316                        Awara  2012      160   5.5
# 343717  188254   tt1587857                       Shatru  1984      150   7.9
# 343718  188254   tt1587857                       Shatru  1984      150   7.9
#
#         votes         director  \
# 0       50191    Jason Woliner
# 1       37295     Aaron Sorkin
# 2       37295     Aaron Sorkin
# 3       37295     Aaron Sorkin
# 4       11829     Ben Wheatley
# ...       ...              ...
# 343714   1240      Halit Refig
# 343715   1240      Halit Refig
# 343716   3550      Rabi Kinagi
# 343717    370  Anjan Choudhury
# 343718    370  Anjan Choudhury
#
#                                                   casting     genres
# 0       ['Sacha Baron Cohen', 'Maria Bakalova', 'Tom H...     Comedy
# 1       ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...      Drama
# 2       ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...    History
# 3       ['Eddie Redmayne', 'Alex Sharp', 'Sacha Baron ...   Thriller
# 4       ['Lily James', 'Armie Hammer', 'Kristin Scott ...      Drama
# ...                                                   ...        ...
# 343714  ['Cüneyt Arkin', 'Nebahat Çehre', 'Birsen Ayda...  Adventure
# 343715  ['Cüneyt Arkin', 'Nebahat Çehre', 'Birsen Ayda...    Fantasy
# 343716  ['Jeet', 'Sayantika Banerjee', 'Mukul Dev', 'A...     Action
# 343717  ['Ranjit Mallick', 'Anup Kumar', 'Chiranjit', ...      Crime
# 343718  ['Ranjit Mallick', 'Anup Kumar', 'Chiranjit', ...      Drama
#
# [343719 rows x 10 columns]

# %% [markdown]
# On peut passer à l'analyse sur le genre, nottamment étudions par exemple la note moyenne par genre pour les 10 genres les plus présents sur la base.

# %%
print(df_genres_split["genres"].unique())
print(len(df_genres_split["genres"].unique()))
# Out:
# ['Comedy' 'Drama' 'History' 'Thriller' 'Mystery' 'Romance' 'Fantasy'
#  'Action' 'Adventure' 'Family' 'Crime' 'Sci-Fi' 'Music' 'Horror'
#  'Biography' 'Sport' 'Animation' 'War' 'Musical' 'Western' 'Film-Noir'
#  'Adult' 'Reality-TV' 'News' 'Documentary' 'Short' 'Talk-Show' 'Game-Show']
# 28

# %% [markdown]
# Il y a 28 genres de films différents dans la base de données

# %%
df_genres_split.groupby("genres")["genres"].count().sort_values(ascending= False).head(10)
# Out:
# genres
# Drama        101427
# Comedy        58087
# Romance       25967
# Action        24061
# Crime         19997
# Thriller      19145
# Horror        16304
# Adventure     14591
# Mystery        8787
# Family         8208
# Name: genres, dtype: int64

# %%
list_genres = ["Drama", "Comedy", "Romance", "Action", "Crime", "Thriller", "Horror",
         "Adventure", "Mystery", "Family"]

# %%
df_genres_10 = df_genres_split[df_genres_split["genres"].isin(list_genres)].reset_index()

# %%
means = df_genres_10.groupby("genres")["rate"].mean()

# %%
sns.set(rc={'figure.figsize':(13,8)}) # taille de la figure
#sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("whitegrid") # style du graphique 
sns.boxplot(x="genres", y="rate", data = df_genres_10,
            palette = "deep").set(xlabel = "Genres", ylabel = "Notations") # classés par genre, histogramme des rates
sns.despine(bottom = True)
plt.title("Histogramme représenatif de la distribution des notes des films classés par genres", size=15)
plt.show()

# %% [markdown]
# ## Visualisation Rémi

# %% [markdown]
# Quelques statistiques descriptives pour mieux connaître la base :

# %%
df.describe().round(2)
# Out:
#             year    runtime       rate       votes
# count  188255.00  188255.00  188255.00   188255.00
# mean     1989.80      95.87       5.95     4411.68
# std        26.14      23.53       1.25    36790.81
# min      1894.00       1.00       1.00        5.00
# 25%      1972.00      84.00       5.20       21.00
# 50%      1998.00      93.00       6.10       82.00
# 75%      2012.00     104.00       6.80      426.00
# max      2021.00     808.00      10.00  2298815.00

# %% [markdown]
# Commentaires : la moyenne de l'année de sortie est plus faible que la médiane ; il existe en effet de nombreux films sortis dans la première moitié du XXème siècle qui tirent la moyenne vers le bas. Pour le runtime, on peut s'étonner que certains films (7 après vérification) ne font qu'une minute !
#
# 50 % des films de notre base font moins de 93 minutes, ce qui paraît relativement faible lorsqu'on regarde la durée des films disponibles en salle au cours des dernières années. Certaines productions peu connues sont sans doute plus courtes, faute de budget (notamment des films étrangers hors Hollywood).

# %% [markdown]
# ### Distribution des durées de films

# %%
ax = df.runtime.hist(bins=100, grid=False, figsize = (10,7),)
ax.set_xlim((0,300))    #90 films font plus de 300 minutes, on ne les considère donc pas ici par souci de visibilité
plt.xlabel('Durée (minutes)')
ax.xaxis.set_major_locator(ticker.MultipleLocator(25))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
plt.ylabel('Nombre de films')
plt.title("Distribution du nombre de films en fonction de leur durée")
# Out:
# Text(0.5, 1.0, 'Distribution du nombre de films en fonction de leur durée')

# %% [markdown]
# ### Note moyenne en fonction de l'année

# %%
df_year_mean = df.groupby("year")["rate"].mean()
df_year_mean
# Out:
# year
# 1894    5.900000
# 1900    6.300000
# 1903    6.500000
# 1906    6.100000
# 1907    6.100000
#           ...
# 2017    5.880255
# 2018    5.794962
# 2019    5.851252
# 2020    5.932312
# 2021    7.400000
# Name: rate, Length: 119, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,7)}) # taille de la figure
# sns.set_style("whitegrid") # style du graphique 
sns.lineplot(x="year", y="rate", data = df,
            palette = "deep").set(xlabel = "Année", ylabel = "Notation") # classés par année, linechart des notes
sns.despine(bottom = True)
plt.title("Note moyenne des films par année, et intervalle à 95%", size=15)
plt.show()

# %% [markdown]
# Commentaires : Avant 1920, l'écart type est trop important pour conclure quoi que ce soit car nous n'avons pas assez de films. Cependant, il semblerait que depuis 1950 la note du film diminue légèrement. Si l'on peut penser que les anciens films sont meilleurs, on peut aussi l'expliquer par le fait que le cinéphile moyen ne va regarder que les meilleurs films anciens, alors qu'il va avoir tendance à visionner tous les films qui sortent aujourd'hui et à les noter systématiquement sur IMDb.
#
# Seul un film sortant en 2021 a été retenu par le cleaning :

# %%
df[df["year"]==2021]
# Out:
#           tconst         title  year  runtime                       genres  \
# 21675  tt2133204  Construction  2021      104  Comedy, Romance
#
#        rate  votes         director  \
# 21675   7.4     32  Malcolm Goodwin
#
#                                                  casting
# 21675  ['Victor Hawks', 'Gino Anthony Pesi', 'Devin R...

# %% [markdown]
# ### Corrélations

# %%
# Basic correlogram
df_corr = df[['year','runtime','rate','votes']]
sns.pairplot(df_corr)
# sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-8b91304f8440> in <module>
#       2 df_corr = df[['year','runtime','rate','votes']]
#       3 sns.pairplot(df_corr)
# ----> 4 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
# Calcul de la matrice de corrélation
corr = df_corr.corr()

# Génération d'un masque pour n'afficher que le triangle inférieur
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Généation d'une palette de couleur adéquate
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Plot de la heatmap
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, cmap = cmap, annot=True, square=True)

# %% [markdown]
# Commentaires : comme vu précédemment, l'année influe négativement sur la note. Autre résultat attendu, l'augmentation de l positivement sur la durée moyenne des films au fil du temps. De plus, les films plus long sont globalement mieux notés.
#
# Corrélation positive du rate et des votes ??????
